# %% [markdown]
# # Showing the output of our ETL - step 1

# %%
import pandas as pd

# %%
our_data = pd.read_csv('./hackathon-riot-data.csv',sep=';',index_col=None)

# %%
our_data.head()
# Out:
#                            gameDate      esportsPlatformId     gameVersion  \
# 0  2023-06-18 18:14:11.781000+00:00  ESPORTSTMNT01:3379581  13.11.512.8126
# 1  2023-02-16 01:59:23.961000+00:00  ESPORTSTMNT02:3150844   13.3.491.6222
# 2  2021-03-13 21:07:56.263000+00:00  ESPORTSTMNT02:1721741   11.5.361.5971
# 3  2021-04-10 11:56:11.980000+00:00  ESPORTSTMNT06:1680685   11.6.364.6814
# 4  2023-06-08 19:47:14.554000+00:00  ESPORTSTMNT06:2815912  13.10.509.8402
#
#    gameDuration  NbWardsPlacedBlue  NbWardsPlacedRed  \
# 0      2068.268                 54                58
# 1      1999.819                  0                 0
# 2      1882.763                 77               143
# 3      1551.344                 42                56
# 4      2246.940                 71                70
#
#    NbControlWardsPlacedBlue  NbControlWardsPlacedRed  NbWardsKilledBlue  \
# 0                        15                       23                  9
# ...

# %%
our_data.columns
# Out:
# Index(['Unnamed: 0', 'gameDate', 'esportsPlatformId', 'gameVersion',
#        'gameDuration', 'NbWardsPlacedBlue', 'NbWardsPlacedRed',
#        'NbControlWardsPlacedBlue', 'NbControlWardsPlacedRed',
#        'NbWardsKilledBlue',
#        ...
#        'TotalCCDurationJgBlue', 'TotalCCDurationMidBlue',
#        'TotalCCDurationADBlue', 'TotalCCDurationSupBlue',
#        'TotalCCDurationTopRed', 'TotalCCDurationJgRed',
#        'TotalCCDurationMidRed', 'TotalCCDurationADRed',
#        'TotalCCDurationSupRed', 'winner'],
#       dtype='object', length=199)

# %%
our_data.loc[3].to_dict()
# Out:
# {'gameDate': '2021-04-10 11:56:11.980000+00:00',
#  'esportsPlatformId': 'ESPORTSTMNT06:1680685',
#  'gameVersion': '11.6.364.6814',
#  'gameDuration': 1551.344,
#  'NbWardsPlacedBlue': 42,
#  'NbWardsPlacedRed': 56,
#  'NbControlWardsPlacedBlue': 23,
#  'NbControlWardsPlacedRed': 17,
#  'NbWardsKilledBlue': 23,
#  'NbWardsKilledRed': 13,
#  'NbControlWardsKilledBlue': 11,
#  'NbControlWardsKilledRed': 14,
#  'NbCampsSecuredBlue': 30,
#  'NbCampsSecuredRed': 41,
#  'NbCampsStolenBlue': 1,
#  'NbCampsStolenRed': 2,
#  'NbScuttlesBlue': 4,
#  'NbScuttlesRed': 4,
#  'NbRiftHeraldsBlue': 1,
#  'NbRiftHeraldsRed': 1,
#  'NbDragonsBlue': 3,
#  'NbDragonsRed': 1,
#  'NbBaronsBlue': 1,
#  'NbBaronsRed': 0,
#  'NbEldersBlue': 0,
#  'NbEldersRed': 0,
#  'NbTowersBlue': 1,
#  'NbTowersRed': 7,
#  'NbPlatesBlue': 4,
#  'NbPlatesRed': 4,
#  'OuterTopBlueTimer': 1064.776,
#  'OuterMidBlueTimer': nan,
#  'OuterBotBlueTimer': nan,
#  'InnerTopBlueTimer': nan,
#  'InnerMidBlueTimer': nan,
# ...
